# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# performing weather check on every single city and printing the log
for city in cities:
    url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid="+weather_api_key
    response = requests.get(url)
    data = response.json()
    try: 
        print(f'City ID: {data["id"]}, Name: {data["name"]}')
        print('============================================')
    except:
        pass
    else:
        print(f'Cloudiness(%): {data["clouds"]["all"]}, Country: {data["sys"]["country"]}, Date: {data["dt"]}, Humidity(%): {data["main"]["humidity"]}, Latitude: {data["coord"]["lat"]}, Longitude: {data["coord"]["lon"]}, Temparature(F): {data["main"]["temp_max"]}, Wind Speed(mph): {data["wind"]["speed"]}')
        print('--------------------------------------------')
# Out:
# City ID: 4031574, Name: Provideniya
# ============================================
# Cloudiness(%): 99, Country: RU, Date: 1592095744, Humidity(%): 81, Latitude: 64.38, Longitude: -173.3, Temparature(F): 281.52, Wind Speed(mph): 2.91
# --------------------------------------------
# City ID: 3421765, Name: Nanortalik
# ============================================
# Cloudiness(%): 100, Country: GL, Date: 1592095745, Humidity(%): 92, Latitude: 60.14, Longitude: -45.24, Temparature(F): 278.33, Wind Speed(mph): 4.38
# --------------------------------------------
# City ID: 964432, Name: Port Alfred
# ============================================
# Cloudiness(%): 81, Country: ZA, Date: 1592095745, Humidity(%): 87, Latitude: -33.59, Longitude: 26.89, Temparature(F): 284.26, Wind Speed(mph): 2.24
# --------------------------------------------
# City ID: 3466704, Name: Castro
# ============================================
# Cloudiness(%): 100, Country: BR, Date: 1592095715, Humidity(%): 96, Latitude: -24.79, Longitude: -50.01, Temparature(F): 288.39, Wind Speed(mph): 1.73
# --------------------------------------------
# City ID: 5962442, Name: Goderich
# ============================================
# Cloudiness(%): 100, Country: CA, Date: 1592095745, Humidity(%): 72, Latitude: 43.75, Longitude: -81.72, Temparature(F): 285.37, Wind Speed(mph): 5.59
# --------------------------------------------
# City ID: 2112309, Name: Katsuura
# ============================================
# Cloudiness(%): 90, Country: JP, Date: 1592095745, Humidity(%): 100, Latitude: 35.13, Longitude: 140.3, Temparature(F): 295.37, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 5847411, Name: Kahului
# ============================================
# Cloudiness(%): 20, Country: US, Date: 1592095477, Humidity(%): 43, Latitude: 20.89, Longitude: -156.47, Temparature(F): 304.15, Wind Speed(mph): 12.3
# --------------------------------------------
# City ID: 1735106, Name: George Town
# ============================================
# Cloudiness(%): 20, Country: MY, Date: 1592095746, Humidity(%): 94, Latitude: 5.41, Longitude: 100.34, Temparature(F): 300.15, Wind Speed(mph): 1
# --------------------------------------------
# City ID: 3652764, Name: Puerto Ayora
# ============================================
# Cloudiness(%): 12, Country: EC, Date: 1592095746, Humidity(%): 91, Latitude: -0.74, Longitude: -90.35, Temparature(F): 295.37, Wind Speed(mph): 3.13
# --------------------------------------------
# City ID: 3471451, Name: Arraial do Cabo
# ============================================
# Cloudiness(%): 0, Country: BR, Date: 1592095498, Humidity(%): 83, Latitude: -22.97, Longitude: -42.03, Temparature(F): 296.98, Wind Speed(mph): 2.08
# --------------------------------------------
# City ID: 3698359, Name: Chicama
# ============================================
# Cloudiness(%): 30, Country: PE, Date: 1592095746, Humidity(%): 79, Latitude: -7.84, Longitude: -79.15, Temparature(F): 291.3, Wind Speed(mph): 2.35
# --------------------------------------------
# City ID: 2022572, Name: Khatanga
# ============================================
# Cloudiness(%): 0, Country: RU, Date: 1592095746, Humidity(%): 47, Latitude: 71.97, Longitude: 102.5, Temparature(F): 283.14, Wind Speed(mph): 5.1
# --------------------------------------------
# City ID: 
# ============================================
# Cloudiness(%): 100, Country: GL, Date: 1592095762, Humidity(%): 90, Latitude: 68.31, Longitude: -53.46, Temparature(F): 274.36, Wind Speed(mph): 6.13
# --------------------------------------------
# City ID: 1283240, Name: Kathmandu
# ============================================
# Cloudiness(%): 40, Country: NP, Date: 1592095571, Humidity(%): 100, Latitude: 27.72, Longitude: 85.32, Temparature(F): 294.15, Wind Speed(mph): 0.42
# --------------------------------------------
# City ID: 3628473, Name: San Cristobal
# ============================================
# Cloudiness(%): 40, Country: VE, Date: 1592095762, Humidity(%): 51, Latitude: 7.77, Longitude: -72.22, Temparature(F): 302.15, Wind Speed(mph): 8.7
# --------------------------------------------
# City ID: 4034551, Name: Faanui
# ============================================
# Cloudiness(%): 10, Country: PF, Date: 1592095748, Humidity(%): 76, Latitude: -16.48, Longitude: -151.75, Temparature(F): 300.29, Wind Speed(mph): 3.8
# --------------------------------------------
# City ID: 2618795, Name: Klaksvík
# ============================================
# Cloudiness(%): 44, Country: FO, Date: 1592095762, Humidity(%): 93, Latitude: 62.23, Longitude: -6.59, Temparature(F): 283.15, Wind Speed(mph): 0.5
# --------------------------------------------
# City ID: 5321473, Name: Winslow
# ============================================
# Cloudiness(%): 1, Country: US, Date: 1592095763, Humidity(%): 8, Latitude: 35.02, Longitude: -110.7, Temparature(F): 305.15, Wind Speed(mph): 13.9
# --------------------------------------------
# City ID: 2163355, Name: Hobart
# ============================================
# Cloudiness(%): 75, Country: AU, Date: 1592095569, Humidity(%): 66, Latitude: -42.88, Longitude: 147.33, Temparature(F): 286.15, Wind Speed(mph): 4.1
# --------------------------------------------
# City ID: 3831208, Name: Qaanaaq
# ============================================
# Cloudiness(%): 0, Country: GL, Date: 1592095763, Humidity(%): 66, Latitude: 77.48, Longitude: -69.36, Temparature(F): 278.42, Wind Speed(mph): 2.34
# --------------------------------------------
# City ID: 932035, Name: Teyateyaneng
# ============================================
# Cloudiness(%): 0, Country: LS, Date: 1592095763, Humidity(%): 80, Latitude: -29.15, Longitude: 27.75, Temparature(F): 270.35, Wind Speed(mph): 1.02
# --------------------------------------------
# City ID: 1816751, Name: Beidao
# ============================================
# Cloudiness(%): 92, Country: CN, Date: 1592095763, Humidity(%): 54, Latitude: 34.57, Longitude: 105.89, Temparature(F): 293.72, Wind Speed(mph): 0.13
# --------------------------------------------
# City ID: 2088122, Name: Port Moresby
# ============================================
# Cloudiness(%): 75, Country: PG, Date: 1592095763, Humidity(%): 83, Latitude: -9.44, Longitude: 147.18, Temparature(F): 302.15, Wind Speed(mph): 5.1
# --------------------------------------------
# City ID: 4021858, Name: Guerrero Negro
# ============================================
# Cloudiness(%): 0, Country: MX, Date: 1592095763, Humidity(%): 65, Latitude: 27.98, Longitude: -114.06, Temparature(F): 293.58, Wind Speed(mph): 10.35
# --------------------------------------------
# City ID: 3838233, Name: Salta
# ============================================
# Cloudiness(%): 90, Country: AR, Date: 1592095764, Humidity(%): 51, Latitude: -24.79, Longitude: -65.41, Temparature(F): 284.15, Wind Speed(mph): 3.1
# --------------------------------------------
# City ID: 2024812, Name: Dul'durga
# ============================================
# Cloudiness(%): 29, Country: RU, Date: 1592095764, Humidity(%): 52, Latitude: 50.68, Longitude: 113.59, Temparature(F): 292.07, Wind Speed(mph): 5.17
# --------------------------------------------
# City ID: 2090021, Name: Namatanai
# ============================================
# Cloudiness(%): 99, Country: PG, Date: 1592095764, Humidity(%): 70, Latitude: -3.67, Longitude: 152.43, Temparature(F): 303.04, Wind Speed(mph): 3.9
# --------------------------------------------
# City ID: 2640351, Name: Peterhead
# ============================================
# Cloudiness(%): 90, Country: GB, Date: 1592095764, Humidity(%): 100, Latitude: 57.51, Longitude: -1.8, Temparature(F): 284.26, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID:
Wind Speed(mph): 6.2
# --------------------------------------------
# City ID: 3382160, Name: Cayenne
# ============================================
# Cloudiness(%): 75, Country: GF, Date: 1592095566, Humidity(%): 100, Latitude: 4.93, Longitude: -52.33, Temparature(F): 297.15, Wind Speed(mph): 1
# --------------------------------------------
# City ID: 3437062, Name: San Juan del Paraná
# ============================================
# Cloudiness(%): 23, Country: PY, Date: 1592095769, Humidity(%): 54, Latitude: -27.3, Longitude: -55.97, Temparature(F): 286.15, Wind Speed(mph): 5.1
# --------------------------------------------
# City ID: 1505991, Name: Igarka
# ============================================
# Cloudiness(%): 100, Country: RU, Date: 1592095769, Humidity(%): 84, Latitude: 67.47, Longitude: 86.58, Temparature(F): 282.43, Wind Speed(mph): 8.19
# --------------------------------------------
# City ID: 3576994, Name: Cockburn Town
# ============================================
# Cloudiness(%): 100, Country: TC, Date: 1592095769, Humidity(%): 79, Latitude: 21.46, Longitude: -71.14, Temparature(F): 301.11, Wind Speed(mph): 4.92
# --------------------------------------------
# City ID: 1633419, Name: Padang
# ============================================
# Cloudiness(%): 20, Country: ID, Date: 1592095769, Humidity(%): 66, Latitude: -0.95, Longitude: 100.35, Temparature(F): 301.22, Wind Speed(mph): 1.55
# --------------------------------------------
# City ID: 3374210, Name: São Filipe
# ============================================
# Cloudiness(%): 68, Country: CV, Date: 1592095770, Humidity(%): 82, Latitude: 14.9, Longitude: -24.5, Temparature(F): 297.63, Wind Speed(mph): 3.92
# --------------------------------------------
# City ID: 3894426, Name: Coyhaique
# ============================================
# Cloudiness(%): 90, Country: CL, Date: 1592095770, Humidity(%): 93, Latitude: -45.58, Longitude: -72.07, Temparature(F): 276.15, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 1651531, Name: Ambon City
# ============================================
# Cloudiness(%): 40, Country: ID, Date: 1592095770, Humidity(%): 94, Latitude: -3.7, Longitude: 128.18, Temparature(F): 299.15, Wind Speed(mph): 3.1
# --------------------------------------------
# City ID: 2038665, Name: Alihe
# ============================================
# Cloudiness(%): 100, Country: CN, Date: 1592095770, Humidity(%): 63, Latitude: 50.57, Longitude: 123.72, Temparature(F): 288.54, Wind Speed(mph): 4.9
# --------------------------------------------
# City ID: 2416061, Name: Sanguéya
# ============================================
# Cloudiness(%): 100, Country: GN, Date: 1592095770, Humidity(%): 87, Latitude: 10.7, Longitude: -14.37, Temparature(F): 299.21, Wind Speed(mph): 1.82
# --------------------------------------------
# City ID: 3572906, Name: Andros Town
# ============================================
# Cloudiness(%): 90, Country: BS, Date: 1592095770, Humidity(%): 94, Latitude: 24.7, Longitude: -77.77, Temparature(F): 295.15, Wind Speed(mph): 5.1
# --------------------------------------------
# City ID: 1850523, Name: Tateyama
# ============================================
# Cloudiness(%): 90, Country: JP, Date: 1592095770, Humidity(%): 100, Latitude: 34.98, Longitude: 139.87, Temparature(F): 295.37, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 5983607, Name: Inuvik
# ============================================
# Cloudiness(%): 75, Country: CA, Date: 1592095771, Humidity(%): 27, Latitude: 68.35, Longitude: -133.72, Temparature(F): 298.15, Wind Speed(mph): 4.1
# --------------------------------------------
# City ID: 1804850, Name: Kaiyuan
# ============================================
# ...
# City ID: 2126785, Name: Belaya Gora
# ============================================
# Cloudiness(%): 0, Country: RU, Date: 1592095819, Humidity(%): 31, Latitude: 68.53, Longitude: 146.42, Temparature(F): 297.82, Wind Speed(mph): 0.12
# --------------------------------------------
# City ID: 2018735, Name: Nyurba
# ============================================
# Cloudiness(%): 0, Country: RU, Date: 1592095819, Humidity(%): 62, Latitude: 63.28, Longitude: 118.33, Temparature(F): 288.3, Wind Speed(mph): 3.48
# --------------------------------------------
# City ID: 2319133, Name: Warri
# ============================================
# Cloudiness(%): 100, Country: NG, Date: 1592095819, Humidity(%): 96, Latitude: 5.52, Longitude: 5.75, Temparature(F): 297.41, Wind Speed(mph): 2.44
# --------------------------------------------
# City ID: 1254709, Name: Tezu
# ============================================
# Cloudiness(%): 96, Country: IN, Date: 1592095820, Humidity(%): 76, Latitude: 27.92, Longitude: 96.17, Temparature(F): 298.54, Wind Speed(mph): 0.32
# --------------------------------------------
# City ID: 778707, Name: Mehamn
# ============================================
# Cloudiness(%): 74, Country: NO, Date: 1592095820, Humidity(%): 55, Latitude: 71.04, Longitude: 27.85, Temparature(F): 284.92, Wind Speed(mph): 2.75
# --------------------------------------------
# City ID: 3388847, Name: São Félix do Xingu
# ============================================
# Cloudiness(%): 0, Country: BR, Date: 1592095820, Humidity(%): 78, Latitude: -6.64, Longitude: -51.99, Temparature(F): 295.75, Wind Speed(mph): 1.32
# --------------------------------------------
# City ID: 5557293, Name: Sitka
# ============================================
# Cloudiness(%): 90, Country: US, Date: 1592095820, Humidity(%): 81, Latitude: 57.05, Longitude: -135.33, Temparature(F): 285.15, Wind Speed(mph): 3.1
# --------------------------------------------
# City ID: 2156643, Name: Mount Gambier
# ============================================
# Cloudiness(%): 75, Country: AU, Date: 1592095820, Humidity(%): 93, Latitude: -37.83, Longitude: 140.77, Temparature(F): 283.15, Wind Speed(mph): 6.2
# --------------------------------------------
# City ID: 2068079, Name: Kwinana
# ============================================
# Cloudiness(%): 90, Country: AU, Date: 1592095820, Humidity(%): 100, Latitude: -32.25, Longitude: 115.77, Temparature(F): 288.71, Wind Speed(mph): 4.1
# --------------------------------------------
# City ID: 2414659, Name: Tokonou
# ============================================
# Cloudiness(%): 94, Country: GN, Date: 1592095820, Humidity(%): 97, Latitude: 9.65, Longitude: -9.78, Temparature(F): 294.25, Wind Speed(mph): 0.66
# --------------------------------------------
# City ID: 3904906, Name: Santa Cruz de la Sierra
# ============================================
# Cloudiness(%): 75, Country: BO, Date: 1592095820, Humidity(%): 82, Latitude: -17.8, Longitude: -63.17, Temparature(F): 289.15, Wind Speed(mph): 12.3
# --------------------------------------------
# City ID: 6539748, Name: Orvieto
# ============================================
# Cloudiness(%): 93, Country: IT, Date: 1592095821, Humidity(%): 85, Latitude: 42.72, Longitude: 12.11, Temparature(F): 290.93, Wind Speed(mph): 0.89
# --------------------------------------------
# City ID: 2381972, Name: Adrar
# ============================================
# Cloudiness(%): 0, Country: MR, Date: 1592095821, Humidity(%): 18, Latitude: 20.5, Longitude: -10.07, Temparature(F): 308.38, Wind Speed(mph): 6.43
# --------------------------------------------
# City ID: 6157536, Name: Stony Plain
# ============================================
# Cloudiness(%): 75, Country: CA, Date: 1592095821, Humidity(%): 68, Latitude: 53.53, Longitude: -114, Temparature(F): 295.15, Wind Speed(mph): 7.2
# --------------------------------------------
# City ID: 3118304, Name: Llanes
# ============================================
# Cloudiness(%): 21, Country: ES, Date: 1592095821, Humidity(%): 97, Latitude: 43.42, Longitude: -4.75, Temparature(F): 288.71, Wind Speed(mph): 0.45
# --------------------------------------------
# City ID: 1650434, Name: Bambanglipuro
# ============================================
# Cloudiness(%): 13, Country: ID, Date: 1592095821, Humidity(%): 80, Latitude: -7.95, Longitude: 110.28, Temparature(F): 300.87, Wind Speed(mph): 2.87
# --------------------------------------------
# City ID: 3491102, Name: Whithorn
# ============================================
# Cloudiness(%): 40, Country: JM, Date: 1592095821, Humidity(%): 88, Latitude: 18.26, Longitude: -78.04, Temparature(F): 300.37, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 3357804, Name: Eenhana
# ============================================
# Cloudiness(%): 0, Country: NA, Date: 1592095822, Humidity(%): 53, Latitude: -17.47, Longitude: 16.33, Temparature(F): 283.15, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 1141857, Name: Gardez
# ============================================
# Cloudiness(%): 0, Country: AF, Date: 1592095822, Humidity(%): 54, Latitude: 33.6, Longitude: 69.23, Temparature(F): 288.33, Wind Speed(mph): 1.29
# --------------------------------------------
# City ID: 2409914, Name: Bonthe
# ============================================
# Cloudiness(%): 100, Country: SL, Date: 1592095822, Humidity(%): 87, Latitude: 7.53, Longitude: -12.51, Temparature(F): 299.18, Wind Speed(mph): 3.08
# --------------------------------------------
# City ID: 333795, Name: Jijiga
# ============================================
# Cloudiness(%): 100, Country: ET, Date: 1592095822, Humidity(%): 88, Latitude: 9.35, Longitude: 42.8, Temparature(F): 290.07, Wind Speed(mph): 5.84
# --------------------------------------------
# City ID: 3984997, Name: San Quintín
# ============================================
# Cloudiness(%): 0, Country: MX, Date: 1592095822, Humidity(%): 63, Latitude: 30.48, Longitude: -115.95, Temparature(F): 292.89, Wind Speed(mph): 9
# --------------------------------------------
# City ID: 3033123, Name: Besançon
# ============================================
# Cloudiness(%): 100, Country: FR, Date: 1592095822, Humidity(%): 100, Latitude: 47.25, Longitude: 6.02, Temparature(F): 285.93, Wind Speed(mph): 1.91
# --------------------------------------------
# City ID: 3451138, Name: Rio Grande
# ============================================
# Cloudiness(%): 0, Country: BR, Date: 1592095545, Humidity(%): 71, Latitude: -32.03, Longitude: -52.1, Temparature(F): 280.93, Wind Speed(mph): 0.45
# --------------------------------------------
# City ID: 1488903, Name: Turukhansk
# ============================================
# Cloudiness(%): 41, Country: RU, Date: 1592095823, Humidity(%): 80, Latitude: 65.82, Longitude: 87.98, Temparature(F): 285.73, Wind Speed(mph): 7.71
# --------------------------------------------
# City ID: 1067565, Name: Beloha
# ============================================
# Cloudiness(%): 0, Country: MG, Date: 1592095823, Humidity(%): 79, Latitude: -25.17, Longitude: 45.05, Temparature(F): 286.76, Wind Speed(mph): 2.43
# --------------------------------------------
# City ID: 3579925, Name: St. George's
# ============================================
# Cloudiness(%): 40, Country: GD, Date: 1592095823, Humidity(%): 74, Latitude: 12.06, Longitude: -61.75, Temparature(F): 301.15, Wind Speed(mph): 7.2
# --------------------------------------------
# City ID: 5915327, Name: Cap-aux-Meules
# ============================================
# Cloudiness(%): 20, Country: CA, Date: 1592095823, Humidity(%): 76, Latitude: 47.38, Longitude: -61.86, Temparature(F): 283.15, Wind Speed(mph): 5.1
# --------------------------------------------
# City ID: 2460954, Name: Araouane
# ============================================
# Cloudiness(%): 0, Country: ML, Date: 1592095823, Humidity(%): 17, Latitude: 18.9, Longitude: -3.53, Temparature(F): 308.06, Wind Speed(mph): 0.21
# --------------------------------------------
# City ID: 2022143, Name: Khuzhir
# ============================================
# Cloudiness(%): 1, Country: RU, Date: 1592095823, Humidity(%): 69, Latitude: 53.19, Longitude: 107.34, Temparature(F): 285.45, Wind Speed(mph): 1.48
# --------------------------------------------
# City ID: 1712961, Name: Gigmoto
# ============================================
# Cloudiness(%): 100, Country: PH, Date: 1592095823, Humidity(%): 77, Latitude: 13.78, Longitude: 124.39, Temparature(F): 302.26, Wind Speed(mph): 3.19
# --------------------------------------------
# City ID: 1808744, Name: Hede
# ============================================
# Cloudiness(%): 47, Country: CN, Date: 1592095824, Humidity(%): 74, Latitude: 33.77, Longitude: 120.25, Temparature(F): 301.09, Wind Speed(mph): 2.46
# --------------------------------------------
# City ID: 1626099, Name: Sumenep
# ============================================
# Cloudiness(%): 100, Country: ID, Date: 1592095824, Humidity(%): 81, Latitude: -7.02, Longitude: 113.87, Temparature(F): 300.51, Wind Speed(mph): 4.21
# --------------------------------------------
# City ID: 2194098, Name: Ahipara
# ============================================
# Cloudiness(%): 55, Country: NZ, Date: 1592095824, Humidity(%): 79, Latitude: -35.17, Longitude: 173.17, Temparature(F): 289.18, Wind Speed(mph): 4.17
# --------------------------------------------
# City ID: 540761, Name: Kropotkin
# ============================================
# Cloudiness(%): 0, Country: RU, Date: 1592095824, Humidity(%): 83, Latitude: 45.44, Longitude: 40.58, Temparature(F): 293.71, Wind Speed(mph): 1.16
# --------------------------------------------
# City ID: 3361142, Name: Springbok
# ============================================
# Cloudiness(%): 0, Country: ZA, Date: 1592095824, Humidity(%): 52, Latitude: -29.66, Longitude: 17.89, Temparature(F): 278.82, Wind Speed(mph): 3.86
# --------------------------------------------
# City ID: 556268, Name: Ostrovnoy
# ============================================
# Cloudiness(%): 45, Country: RU, Date: 1592095824, Humidity(%): 60, Latitude: 68.05, Longitude: 39.51, Temparature(F): 286.6, Wind Speed(mph): 8.18
# --------------------------------------------
# City ID: 2027109, Name: Barguzin
# ============================================
# Cloudiness(%): 35, Country: RU, Date: 1592095825, Humidity(%): 51, Latitude: 53.62, Longitude: 109.62, Temparature(F): 292.44, Wind Speed(mph): 2.16
# --------------------------------------------
# City ID: 5261790, Name: Marathon
# ============================================
# Cloudiness(%): 1, Country: US, Date: 1592095825, Humidity(%): 36, Latitude: 44.9, Longitude: -89.77, Temparature(F): 290.15, Wind Speed(mph): 5.7
# --------------------------------------------
# City ID: 293842, Name: Kiryat Gat
# ============================================
# Cloudiness(%): 0, Country: IL, Date: 1592095560, Humidity(%): 79, Latitude: 31.61, Longitude: 34.76, Temparature(F): 295.93, Wind Speed(mph): 0.89
# --------------------------------------------
# City ID: 3408269, Name: Afuá
# ============================================
# Cloudiness(%): 91, Country: BR, Date: 1592095825, Humidity(%): 91, Latitude: -0.16, Longitude: -50.39, Temparature(F): 297.47, Wind Speed(mph): 1.98
# --------------------------------------------
# City ID: 1699246, Name: Moog
# ============================================
# Cloudiness(%): 100, Country: PH, Date: 1592095825, Humidity(%): 77, Latitude: 8.6, Longitude: 124.47, Temparature(F): 302.04, Wind Speed(mph): 0.89
# --------------------------------------------
# City ID: 3910094, Name: Monteagudo
# ============================================
# Cloudiness(%): 100, Country: BO, Date: 1592095825, Humidity(%): 75, Latitude: -19.82, Longitude: -63.98, Temparature(F): 285.89, Wind Speed(mph): 3.4
# --------------------------------------------
# City ID: 3385658, Name: Uruçuí
# ============================================
# Cloudiness(%): 28, Country: BR, Date: 1592095825, Humidity(%): 61, Latitude: -7.23, Longitude: -44.56, Temparature(F): 297.32, Wind Speed(mph): 2.48
# --------------------------------------------
# City ID: 797213, Name: Pervomayskoye
# ============================================
# Cloudiness(%): 13, Country: RU, Date: 1592095825, Humidity(%): 67, Latitude: 43.92, Longitude: 46.71, Temparature(F): 290.86, Wind Speed(mph): 1.89
# --------------------------------------------
# City ID: 1328121, Name: Bogale
# ============================================
# Cloudiness(%): 85, Country: MM, Date: 1592095826, Humidity(%): 82, Latitude: 16.28, Longitude: 95.4, Temparature(F): 301.78, Wind Speed(mph): 3.61
# --------------------------------------------
# City ID: 2242001, Name: Caxito
# ============================================
# Cloudiness(%): 75, Country: AO, Date: 1592095826, Humidity(%): 83, Latitude: -8.58, Longitude: 13.66, Temparature(F): 295.15, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 2657832, Name: Aberdeen
# ============================================
# Cloudiness(%): 90, Country: GB, Date: 1592095538, Humidity(%): 100, Latitude: 57.14, Longitude: -2.1, Temparature(F): 284.82, Wind Speed(mph): 1.5
# --------------------------------------------
# City ID: 292223, Name: Dubai
# ============================================
# Cloudiness(%): 0, Country: AE, Date: 1592095618, Humidity(%): 79, Latitude: 25.26, Longitude: 55.3, Temparature(F): 305.15, Wind Speed(mph): 2.1
# --------------------------------------------
# City ID: 1488414, Name: Urengoy
# ============================================
# Cloudiness(%): 100, Country: RU, Date: 1592095826, Humidity(%): 46, Latitude: 65.97, Longitude: 78.37, Temparature(F): 284.84, Wind Speed(mph): 10.76
# --------------------------------------------
# City ID: 2079582, Name: Alyangula
# ============================================
# Cloudiness(%): 90, Country: AU, Date: 1592095826, Humidity(%): 69, Latitude: -13.85, Longitude: 136.42, Temparature(F): 300.15, Wind Speed(mph): 2.6
# --------------------------------------------
# City ID: 3175096, Name: Laas
# ============================================
# Cloudiness(%): 90, Country: IT, Date: 1592095826, Humidity(%): 87, Latitude: 46.62, Longitude: 10.7, Temparature(F): 283.15, Wind Speed(mph): 1.64
# --------------------------------------------
# City ID: 2639577, Name: Reading
# ============================================
# Cloudiness(%): 0, Country: GB, Date: 1592095791, Humidity(%): 87, Latitude: 51.46, Longitude: -0.97, Temparature(F): 288.15, Wind Speed(mph): 2.1
# --------------------------------------------
# City ID: 5856516, Name: ‘Āhuimanu
# ============================================
# Cloudiness(%): 20, Country: US, Date: 1592095827, Humidity(%): 45, Latitude: 21.44, Longitude: -157.84, Temparature(F): 304.15, Wind Speed(mph): 6.7
# --------------------------------------------
# City ID: 2450173, Name: Taoudenni
# ============================================
# Cloudiness(%): 0, Country: ML, Date: 1592095827, Humidity(%): 13, Latitude: 22.68, Longitude: -3.98, Temparature(F): 310.32, Wind Speed(mph): 8.13
# --------------------------------------------
# City ID: 1796236, Name: Shanghai
# ============================================
# Cloudiness(%): 96, Country: CN, Date: 1592095428, Humidity(%): 74, Latitude: 31.22, Longitude: 121.46, Temparature(F): 305.93, Wind Speed(mph): 2
# --------------------------------------------
# City ID: 608270, Name: Shubarshi
# ============================================
# Cloudiness(%): 0, Country: KZ, Date: 1592095827, Humidity(%): 82, Latitude: 48.59, Longitude: 57.19, Temparature(F): 293.27, Wind Speed(mph): 3.37
# --------------------------------------------
# City ID: 480884, Name: Bolshoye Nagatkino
# ============================================
# Cloudiness(%): 37, Country: RU, Date: 1592095827, Humidity(%): 81, Latitude: 54.52, Longitude: 47.97, Temparature(F): 284.15, Wind Speed(mph): 3
# --------------------------------------------
# City ID: 907111, Name: Mazabuka
# ============================================
# Cloudiness(%): 10, Country: ZM, Date: 1592095827, Humidity(%): 93, Latitude: -15.86, Longitude: 27.75, Temparature(F): 286.11, Wind Speed(mph): 4.32
# --------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# performing weather check on every single city and appending in csv
with open(output_data_file,'w', encoding='utf-8', newline='') as csv_file:
    writer=csv.writer(csv_file)
    writer.writerow(["City_ID", "City_Name", "Cloudiness (%)", "Country", "Date", "Humidity (%)", "Latitude", "Longitude", "Temperature (F)", "Wind Speed (mph)"])

    print("Exporting to CSV. Please wait ...")
    for city in cities:
        url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid="+weather_api_key
        response = requests.get(url)
        data = response.json()
        try: 
            city_id = data["name"]
        except:
            pass
        else:
            writer.writerow([data["id"], data["name"], data["clouds"]["all"], data["sys"]["country"], data["dt"], data["main"]["humidity"], data["coord"]["lat"], data["coord"]["lon"], data["main"]["temp_max"], data["wind"]["speed"]])
# Out:
# Exporting to CSV. Please wait ...

# %%
# after exporting create the dataframe
print("Export Complete! Creating Data Frame. Please wait ...")
city_weather_data = pd.read_csv(output_data_file)
city_weather_data.head(10)
# Out:
# Export Complete! Creating Data Frame. Please wait ...
#    City_ID        City_Name  Cloudiness (%) Country        Date  Humidity (%)  \
# 0  4031574      Provideniya              99      RU  1592095744            81
# 1  3421765       Nanortalik             100      GL  1592095745            92
# 2   964432      Port Alfred              81      ZA  1592095745            87
# 3  3466704           Castro             100      BR  1592095715            96
# 4  5962442         Goderich             100      CA  1592095745            72
# 5  2112309         Katsuura              90      JP  1592095745           100
# 6  5847411          Kahului              20      US  1592095477            43
# 7  1735106      George Town              20      MY  1592095746            94
# 8  3652764     Puerto Ayora              12      EC  1592095746            91
# 9  3471451  Arraial do Cabo               0      BR  1592095498            83
#
#    Latitude  Longitude  Temperature (F)  Wind Speed (mph)
# 0     64.38    -173.30           281.52              2.91
# 1     60.14     -45.24           278.33              4.38
# 2    -33.59      26.89           284.26              2.24
# 3    -24.79     -50.01           288.39              1.73
# 4     43.75     -81.72           285.37              5.59
# 5     35.13     140.30           295.37              1.50
# 6     20.89    -156.47           304.15             12.30
# 7      5.41     100.34           300.15              1.00
# 8     -0.74     -90.35           295.37              3.13
# 9    -22.97     -42.03           296.98              2.08

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check for cities with humidity > 100%
city_humidity_more_than_hundred = city_weather_data.loc[(city_weather_data["Humidity (%)"] > 100)]
no_of_cities_humidity_more_than_hundred = city_humidity_more_than_hundred["City_Name"].count()
print(f'Total number of cities where the humidity is more than 100%: {no_of_cities_humidity_more_than_hundred}')
# Out:
# Total number of cities where the humidity is more than 100%: 0

# %% [markdown]
# # skipping the following steps as there is no city with humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = city_weather_data["Latitude"]
temparature = city_weather_data["Temperature (F)"]
_=plt.scatter(latitude, temparature)
_=plt.title("Latitude vs Temperature (F) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Temperature (F)")
plt.savefig("../output_data/lat_temp.png")
print("Observation: The temperature rises as we move away from either end of the Latitude and get closer to the equator")
# Out:
# Observation: The temperature rises as we move away from either end of the Latitude and get closer to the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity = city_weather_data["Humidity (%)"]
_=plt.scatter(latitude, temparature)

_=plt.title("Latitude vs Humidity (%) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_humid.png")
print("Observation: The humidity rises as we move away from either end of the Latitude and get closer to the equator")
# Out:
# Observation: The humidity rises as we move away from either end of the Latitude and get closer to the equator

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudiness = city_weather_data["Cloudiness (%)"]
_=plt.scatter(latitude, cloudiness)

_=plt.title("Latitude vs Cloudiness (%) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/lat_cloud.png")
print("Observation: There seem to be no correlation between the Latitude and Cloudiness")
# Out:
# Observation: There seem to be no correlation between the Latitude and Cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windspeed = city_weather_data["Wind Speed (mph)"]
_=plt.scatter(latitude, windspeed)

_=plt.title("Latitude vs Wind Speed (mph) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/lat_wind.png")
print("Observation: The wind speed is mostly evenly distributed across Latitude points. However, there are quite a few outliers between -20 & +40 Latitude")
# Out:
# Observation: The wind speed is mostly evenly distributed across Latitude points. However, there are quite a few outliers between -20 & +40 Latitude

# %% [markdown]
# ## Linear Regression

# %%
# function to calculate Linear Regression plots
def calculate_linear_regression(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    return (x * slope + intercept)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_city_weather_data = city_weather_data.loc[(city_weather_data["Latitude"] >= 0)]
southern_city_weather_data = city_weather_data.loc[(city_weather_data["Latitude"] < 0)]
# Out:
#     City_ID        City_Name  Cloudiness (%) Country        Date  \
# 2    964432      Port Alfred              81      ZA  1592095745
# 3   3466704           Castro             100      BR  1592095715
# 8   3652764     Puerto Ayora              12      EC  1592095746
# 9   3471451  Arraial do Cabo               0      BR  1592095498
# 10  3698359          Chicama              30      PE  1592095746
#
#     Humidity (%)  Latitude  Longitude  Temperature (F)  Wind Speed (mph)
# 2             87    -33.59      26.89           284.26              2.24
# 3             96    -24.79     -50.01           288.39              1.73
# 8             91     -0.74     -90.35           295.37              3.13
# 9             83    -22.97     -42.03           296.98              2.08
# 10            79     -7.84     -79.15           291.30              2.35

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
temparature = northern_city_weather_data["Temperature (F)"]
regress_values = calculate_linear_regression(temparature, latitude)
_=plt.scatter(temparature, latitude)
_=plt.plot(temparature,regress_values,"r-")
_=plt.title("Northern Hemisphere - Max Temp (F) vs Latitude  Plot")
_=plt.xlabel("Max Temp (F)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_temp.png")
print("Observation: The temperature rises as we get closer to the equator")
# Out:
# Observation: The temperature rises as we get closer to the equator

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
temparature = southern_city_weather_data["Temperature (F)"]
regress_values = calculate_linear_regression(temparature, latitude)
_=plt.scatter(temparature, latitude)
_=plt.plot(temparature,regress_values,"r-")
_=plt.title("Southern Hemisphere - Max Temp (F) vs Latitude  Plot")
_=plt.xlabel("Max Temp (F)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_temp.png")
print("Observation: The temperature rises as we get closer to the equator")
# Out:
# Observation: The temperature rises as we get closer to the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
humidity = northern_city_weather_data["Humidity (%)"]
regress_values = calculate_linear_regression(humidity, latitude)
_=plt.scatter(humidity, latitude)
_=plt.plot(humidity,regress_values,"r-")
_=plt.title("Northern Hemisphere - Humidity (%) vs Latitude  Plot")
_=plt.xlabel("Humidity (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_humid.png")
print("Observation: The humidity is pretty evenly distributed within Northern Hemisphere")
# Out:
# Observation: The humidity is pretty evenly distributed within Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
humidity = southern_city_weather_data["Humidity (%)"]
regress_values = calculate_linear_regression(humidity, latitude)
_=plt.scatter(humidity, latitude)
_=plt.plot(humidity,regress_values,"r-")
_=plt.title("Southern Hemisphere - Humidity (%) vs Latitude  Plot")
_=plt.xlabel("Humidity (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_humid.png")
print("Observation: The humidity is pretty evenly distributed within Southern Hemisphere")
# Out:
# Observation: The humidity is pretty evenly distributed within Northern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
cloudiness = northern_city_weather_data["Cloudiness (%)"]
regress_values = calculate_linear_regression(cloudiness, latitude)
_=plt.scatter(cloudiness, latitude)
_=plt.plot(cloudiness,regress_values,"r-")
_=plt.title("Northern Hemisphere - Cloudiness (%) vs Latitude  Plot")
_=plt.xlabel("Cloudiness (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_cloud.png")
print("Observation: The humidity is not significantly effected by Latitude")
# Out:
# Observation: The humidity is not significantly effected by Latitude

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
cloudiness = southern_city_weather_data["Cloudiness (%)"]
regress_values = calculate_linear_regression(cloudiness, latitude)
_=plt.scatter(cloudiness, latitude)
_=plt.plot(cloudiness,regress_values,"r-")
_=plt.title("Southern Hemisphere - Cloudiness (%) vs Latitude  Plot")
_=plt.xlabel("Cloudiness (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_cloud.png")
print("Observation: The cloudiness is pretty evenly distributed within Southern Hemisphere")
# Out:
# Observation: The cloudiness is pretty evenly distributed within Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
windspeed = northern_city_weather_data["Wind Speed (mph)"]
regress_values = calculate_linear_regression(windspeed, latitude)
_=plt.scatter(windspeed, latitude)
_=plt.plot(windspeed,regress_values,"r-")
_=plt.title("Northern Hemisphere - Wind Speed (mph) vs Latitude  Plot")
_=plt.xlabel("Wind Speed (mph))")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_wind.png")
print("Observation: The wind speed is pretty evenly distributed within Northern Hemisphere")
# Out:
# Observation: The wind speed is pretty evenly distributed within Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
windspeed = southern_city_weather_data["Wind Speed (mph)"]
regress_values = calculate_linear_regression(windspeed, latitude)
_=plt.scatter(windspeed, latitude)
_=plt.plot(windspeed,regress_values,"r-")
_=plt.title("Southern Hemisphere - Wind Speed (mph) vs Latitude  Plot")
_=plt.xlabel("Wind Speed (mph)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_wind.png")
print("Observation: The humidity is pretty evenly distributed within Southern Hemisphere")
# Out:
# Observation: The humidity is pretty evenly distributed within Southern Hemisphere
