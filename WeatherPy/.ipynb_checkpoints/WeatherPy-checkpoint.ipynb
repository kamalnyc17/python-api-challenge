# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# performing weather check on every single city and printing the log
for city in cities:
    # making api call for each city
    url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid="+weather_api_key
    response = requests.get(url)
    data = response.json()
    
    # checking the sanctity of data and then logging on the screen
    try:        
        # convert max temperature from Kelvin to Fahrenheit
        kelvin_max_temp = float(data["main"]["temp_max"])
        fahrenheit_max_temp = round(9/5 * (kelvin_max_temp - 273) + 32, 2)
        # convert wind speed: meters/sec to miles per hour
        wind_speed_mps = float(data["wind"]["speed"])
        wind_speed_mph = round(wind_speed_mps*2.236936, 2)
        print(f'City ID: {data["id"]}, Name: {data["name"]} Cloudiness(%): {data["clouds"]["all"]}, Country: {data["sys"]["country"]}, Date: {data["dt"]}, Humidity(%): {data["main"]["humidity"]}, Latitude: {data["coord"]["lat"]}, Longitude: {data["coord"]["lon"]}, Temparature(F): {fahrenheit_max_temp}, Wind Speed(mph): {wind_speed_mph}')
    except:
        pass
# Out:
# City ID: 5972291, Name: Havre-St-Pierre Cloudiness(%): 1, Country: CA, Date: 1592166333, Humidity(%): 53, Latitude: 50.23, Longitude: -63.6, Temparature(F): 55.67, Wind Speed(mph): 18.34
# City ID: 6113406, Name: Prince Rupert Cloudiness(%): 90, Country: CA, Date: 1592166038, Humidity(%): 76, Latitude: 54.32, Longitude: -130.32, Temparature(F): 55.67, Wind Speed(mph): 4.7
# City ID: 6089245, Name: Norman Wells Cloudiness(%): 75, Country: CA, Date: 1592166334, Humidity(%): 48, Latitude: 65.28, Longitude: -126.83, Temparature(F): 66.47, Wind Speed(mph): 17.22
# City ID: 2110227, Name: Butaritari Cloudiness(%): 64, Country: KI, Date: 1592166334, Humidity(%): 71, Latitude: 3.07, Longitude: 172.79, Temparature(F): 82.85, Wind Speed(mph): 6.98
# City ID: 2065594, Name: Mount Isa Cloudiness(%): 0, Country: AU, Date: 1592166186, Humidity(%): 41, Latitude: -20.73, Longitude: 139.5, Temparature(F): 61.07, Wind Speed(mph): 9.17
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# performing weather check on every single city and appending in csv
with open(output_data_file,'w', encoding='utf-8', newline='') as csv_file:
    writer=csv.writer(csv_file)
    writer.writerow(["City_ID", "City_Name", "Cloudiness (%)", "Country", "Date", "Humidity (%)", "Latitude", "Longitude", "Temperature (F)", "Wind Speed (mph)"])

    for city in cities:
        url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid="+weather_api_key
        response = requests.get(url)
        data = response.json()
        try: 
            # convert max temperature from Kelvin to Fahrenheit
            kelvin_max_temp = float(data["main"]["temp_max"])
            fahrenheit_max_temp = round(9/5 * (kelvin_max_temp - 273) + 32, 2)
            # convert wind speed: meters/sec to miles per hour
            wind_speed_mps = float(data["wind"]["speed"])
            wind_speed_mph = round(wind_speed_mps*2.236936, 2)
            # writing to csv
            writer.writerow([data["id"], data["name"], data["clouds"]["all"], data["sys"]["country"], data["dt"], data["main"]["humidity"], data["coord"]["lat"], data["coord"]["lon"], fahrenheit_max_temp, wind_speed_mph])
        except:
            pass

# %%
# after exporting create the dataframe
city_weather_data = pd.read_csv(output_data_file)
city_weather_data.head(10)
# Out:
#    City_ID                      City_Name  Cloudiness (%) Country        Date  \
# 0  5972291                Havre-St-Pierre               1      CA  1592166333
# 1  6113406                  Prince Rupert              90      CA  1592166038
# 2  6089245                   Norman Wells              75      CA  1592166334
# 3  2110227                     Butaritari              64      KI  1592166334
# 4  2065594                      Mount Isa               0      AU  1592166186
# 5  5848280                          Kapaa              75      US  1592166334
# 6  1507636                       Chunskiy              44      RU  1592166334
# 7  1490796                     Strezhevoy              75      RU  1592166072
# 8  2980915  Arrondissement de Saint-Denis               6      FR  1592166335
# 9  3369157                      Cape Town              75      ZA  1592165701
#
#    Humidity (%)  Latitude  Longitude  Temperature (F)  Wind Speed (mph)
# ...

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check for cities with humidity > 100%
city_humidity_more_than_hundred = city_weather_data.loc[(city_weather_data["Humidity (%)"] > 100)]
no_of_cities_humidity_more_than_hundred = city_humidity_more_than_hundred["City_Name"].count()
print(f'Total number of cities where the humidity is more than 100%: {no_of_cities_humidity_more_than_hundred}')
# Out:
# Total number of cities where the humidity is more than 100%: 0

# %% [markdown]
# # skipping the following steps as there is no city with humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = city_weather_data["Latitude"]
temparature = city_weather_data["Temperature (F)"]
_=plt.scatter(latitude, temparature)
_=plt.title("Latitude vs Temperature (F) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Temperature (F)")
plt.savefig("../output_data/lat_temp.png")
print("Observation: The temperature rises as we move away from either end of the Latitude and get closer to the equator")
# Out:
# Observation: The temperature rises as we move away from either end of the Latitude and get closer to the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity = city_weather_data["Humidity (%)"]
_=plt.scatter(latitude, temparature)

_=plt.title("Latitude vs Humidity (%) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_humid.png")
print("Observation: The humidity rises as we move away from either end of the Latitude and get closer to the equator")
# Out:
# Observation: The humidity rises as we move away from either end of the Latitude and get closer to the equator

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudiness = city_weather_data["Cloudiness (%)"]
_=plt.scatter(latitude, cloudiness)

_=plt.title("Latitude vs Cloudiness (%) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/lat_cloud.png")
print("Observation: There seem to be no correlation between the Latitude and Cloudiness")
# Out:
# Observation: There seem to be no correlation between the Latitude and Cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windspeed = city_weather_data["Wind Speed (mph)"]
_=plt.scatter(latitude, windspeed)

_=plt.title("Latitude vs Wind Speed (mph) Plot")
_=plt.xlabel("Latitude")
_=plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/lat_wind.png")
print("Observation: The wind speed is mostly evenly distributed across Latitude points. However, there are few outliers in Northern Hemisphere")
# Out:
# Observation: The wind speed is mostly evenly distributed across Latitude points. However, there are few outliers in Northern Hemisphere

# %% [markdown]
# ## Linear Regression

# %%
# function to calculate Linear Regression plots
def calculate_linear_regression(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    return (x * slope + intercept)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_city_weather_data = city_weather_data.loc[(city_weather_data["Latitude"] >= 0)]
southern_city_weather_data = city_weather_data.loc[(city_weather_data["Latitude"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
temparature = northern_city_weather_data["Temperature (F)"]
regress_values = calculate_linear_regression(temparature, latitude)
_=plt.scatter(temparature, latitude)
_=plt.plot(temparature,regress_values,"r-")
_=plt.title("Northern Hemisphere - Max Temp (F) vs Latitude  Plot")
_=plt.xlabel("Max Temp (F)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_temp.png")
print("Observation: Temperature rises as we get further away equator")
# Out:
# Observation: Temperature rises as we get further away equator

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
temparature = southern_city_weather_data["Temperature (F)"]
regress_values = calculate_linear_regression(temparature, latitude)
_=plt.scatter(temparature, latitude)
_=plt.plot(temparature,regress_values,"r-")
_=plt.title("Southern Hemisphere - Max Temp (F) vs Latitude  Plot")
_=plt.xlabel("Max Temp (F)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_temp.png")
print("Observation: Temperature rises as we get closer to the equator")
# Out:
# Observation: Temperature rises as we get closer to the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
humidity = northern_city_weather_data["Humidity (%)"]
regress_values = calculate_linear_regression(humidity, latitude)
_=plt.scatter(humidity, latitude)
_=plt.plot(humidity,regress_values,"r-")
_=plt.title("Northern Hemisphere - Humidity (%) vs Latitude  Plot")
_=plt.xlabel("Humidity (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_humid.png")
print("Observation: Most cities in Northern Hemisphere have higher humidity and it's pretty evenly distributed")
# Out:
# Observation: Most cities in Northern Hemisphere have higher humidity and it's pretty evenly distributed

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
humidity = southern_city_weather_data["Humidity (%)"]
regress_values = calculate_linear_regression(humidity, latitude)
_=plt.scatter(humidity, latitude)
_=plt.plot(humidity,regress_values,"r-")
_=plt.title("Southern Hemisphere - Humidity (%) vs Latitude  Plot")
_=plt.xlabel("Humidity (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_humid.png")
print("Observation: The humidity is pretty evenly distributed within Southern Hemisphere")
# Out:
# Observation: The humidity is pretty evenly distributed within Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
cloudiness = northern_city_weather_data["Cloudiness (%)"]
regress_values = calculate_linear_regression(cloudiness, latitude)
_=plt.scatter(cloudiness, latitude)
_=plt.plot(cloudiness,regress_values,"r-")
_=plt.title("Northern Hemisphere - Cloudiness (%) vs Latitude  Plot")
_=plt.xlabel("Cloudiness (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_cloud.png")
print("Observation: The Cloudiness is not significantly effected by Latitude")
# Out:
# Observation: The Cloudiness is not significantly effected by Latitude

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
cloudiness = southern_city_weather_data["Cloudiness (%)"]
regress_values = calculate_linear_regression(cloudiness, latitude)
_=plt.scatter(cloudiness, latitude)
_=plt.plot(cloudiness,regress_values,"r-")
_=plt.title("Southern Hemisphere - Cloudiness (%) vs Latitude  Plot")
_=plt.xlabel("Cloudiness (%)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_cloud.png")
print("Observation: The cloudiness is pretty evenly distributed within Southern Hemisphere")
# Out:
# Observation: The cloudiness is pretty evenly distributed within Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = northern_city_weather_data["Latitude"]
windspeed = northern_city_weather_data["Wind Speed (mph)"]
regress_values = calculate_linear_regression(windspeed, latitude)
_=plt.scatter(windspeed, latitude)
_=plt.plot(windspeed,regress_values,"r-")
_=plt.title("Northern Hemisphere - Wind Speed (mph) vs Latitude  Plot")
_=plt.xlabel("Wind Speed (mph))")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/north_lat_wind.png")
print("Observation: Barring few outliers towards the north pole, most cities in  Northern Hemisphere  have lower to  moderate wind speed")
# Out:
# Observation: Barring few outliers towards the north pole, most cities in  Northern Hemisphere  have lower to  moderate wind speed

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = southern_city_weather_data["Latitude"]
windspeed = southern_city_weather_data["Wind Speed (mph)"]
regress_values = calculate_linear_regression(windspeed, latitude)
_=plt.scatter(windspeed, latitude)
_=plt.plot(windspeed,regress_values,"r-")
_=plt.title("Southern Hemisphere - Wind Speed (mph) vs Latitude  Plot")
_=plt.xlabel("Wind Speed (mph)")
_=plt.ylabel("Latitude")
plt.savefig("../output_data/south_lat_wind.png")
print("Observation: Barring few outliers towards the equator, most cities in Southern Hemisphere have lower to moderate wind speed")
# Out:
# Observation: Barring few outliers towards the equator, most cities in Southern Hemisphere have lower to moderate wind speed

# %% [markdown]
# # Observation
# ### 1. Temperature rises as we move away from either end of the Latitude and get closer to the equator
# ### 2. Humidity increases as we get closer to the equator move away from either end of the Latitude
# ### 3. There seem to be no correlation between the Latitude and Cloudiness

# %% [markdown]
# # Explanation of the above Observation
# ### 1. The Latitude vs. Temperature Plot clearly shows that cities that are closer to north and south pole has much less temparature compare to the cities that are closer to the equator. We see a steady increase in temparature as we move away from either end of the Latitude
# ### 2. The Latitude vs. Humidity Plot clearly shows a steady increase in humidity as we move away from either end of the Latitude. Cities that are closer to north and south pole has much less humidity compare to the cities that are closer to the equator.
# ### 3. The Latitude vs. Cloudiness Plot shows a pretty even distribution of cloudiness across various latitudes and there is direct correlation between the Latitude and Cloudiness.
